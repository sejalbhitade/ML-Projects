# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.linear_model import LogisticRegression
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier,DecisionTreeRegressor
from sklearn import tree
from sklearn.metrics import classification_report,accuracy_score


import warnings
warnings.filterwarnings('ignore')

# %%
df=pd.read_csv('bank.csv')
df.head()
# Out:
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   59    0        1          1        0     2343        1     0        2
# 1   56    0        1          1        0       45        0     0        2
# 2   41    9        1          1        0     1270        1     0        2
# 3   55    7        1          1        0     2476        1     0        2
# 4   54    0        1          2        0      184        0     0        2
#
#    day  month  duration  campaign  pdays  previous  poutcome  deposit
# 0    5      8      1042         1     -1         0         3        1
# 1    5      8      1467         1     -1         0         3        1
# 2    5      8      1389         1     -1         0         3        1
# 3    5      8       579         1     -1         0         3        1
# 4    5      8       673         2     -1         0         3        1
#    age  job  marital  education  default  balance  housing  loan  contact  \
# 0   59    0        1          1        0     2343        1     0        2
# 1   56    0        1          1        0       45        0     0        2
# 2   41    9        1          1        0     1270        1     0        2
# 3   55    7        1          1        0     2476        1     0        2
# 4   54    0        1          2        0      184        0     0        2
#
#    day  month  duration  campaign  pdays  previous  poutcome  deposit
# 0    5      8      1042         1     -1         0         3        1
# 1    5      8      1467         1     -1         0         3        1
# 2    5      8      1389         1     -1         0         3        1
# 3    5      8       579         1     -1         0         3        1
# 4    5      8       673         2     -1         0         3        1

# %%
x=df.iloc[:,:-1]
y=df.iloc[:,-1]

# %%
from sklearn.model_selection import train_test_split
xtrain,xtest,ytrain,ytest=train_test_split(x,y,test_size=0.30,random_state=1)

# %% [markdown]
# # Bagging

# %%
from sklearn.ensemble import BaggingClassifier
bg=BaggingClassifier(LogisticRegression())
bg.fit(xtrain,ytrain)
ypred=bg.predict(xtest)
cr=classification_report(ytest,ypred)
print(f"classification report{cr}")
# Out:
# classification report              precision    recall  f1-score   support
#
#            0       0.76      0.81      0.79      1760
#            1       0.77      0.72      0.75      1589
#
#     accuracy                           0.77      3349
#    macro avg       0.77      0.77      0.77      3349
# weighted avg       0.77      0.77      0.77      3349
#
# classification report              precision    recall  f1-score   support
#
#            0       0.76      0.81      0.79      1760
#            1       0.77      0.72      0.75      1589
#
#     accuracy                           0.77      3349
#    macro avg       0.77      0.77      0.77      3349
# weighted avg       0.77      0.77      0.77      3349

# %%
bg=BaggingClassifier(DecisionTreeClassifier())
bg.fit(xtrain,ytrain)
ypred=bg.predict(xtest)
cr=classification_report(ytest,ypred)
print(f"classification report{cr}")
# Out:
# classification report              precision    recall  f1-score   support
#
#            0       0.84      0.84      0.84      1760
#            1       0.83      0.82      0.82      1589
#
#     accuracy                           0.83      3349
#    macro avg       0.83      0.83      0.83      3349
# weighted avg       0.83      0.83      0.83      3349
#
# classification report              precision    recall  f1-score   support
#
#            0       0.84      0.84      0.84      1760
#            1       0.83      0.82      0.82      1589
#
#     accuracy                           0.83      3349
#    macro avg       0.83      0.83      0.83      3349
# weighted avg       0.83      0.83      0.83      3349

# %%
from sklearn.ensemble import RandomForestClassifier
rf=RandomForestClassifier()
rf.fit(xtrain,ytrain)
ypred=rf.predict(xtest)
cr=classification_report(ytest,ypred)
print(f"classification report{cr}")
# Out:
# classification report              precision    recall  f1-score   support
#
#            0       0.88      0.82      0.85      1760
#            1       0.81      0.87      0.84      1589
#
#     accuracy                           0.84      3349
#    macro avg       0.84      0.84      0.84      3349
# weighted avg       0.85      0.84      0.84      3349
#
# classification report              precision    recall  f1-score   support
#
#            0       0.88      0.82      0.85      1760
#            1       0.81      0.87      0.84      1589
#
#     accuracy                           0.84      3349
#    macro avg       0.84      0.84      0.84      3349
# weighted avg       0.85      0.84      0.84      3349

# %%
from sklearn.ensemble import VotingClassifier

# %%
models=[]
models.append(("logistic regression" ,LogisticRegression()))
models.append(("Decision Tree" ,DecisionTreeClassifier()))
models
# Out:
# [('logistic regression', LogisticRegression()),
#  ('Decision Tree', DecisionTreeClassifier())]
# [('logistic regression', LogisticRegression()),
#  ('Decision Tree', DecisionTreeClassifier())]

# %%
vc=VotingClassifier(estimators=models)
vc.fit(xtrain,ytrain)
ypred=vc.predict(xtest)
cr=classification_report(ytest,ypred)
print(f"classification report {cr}")
# Out:
# classification report               precision    recall  f1-score   support
#
#            0       0.70      0.88      0.78      1760
#            1       0.82      0.59      0.68      1589
#
#     accuracy                           0.74      3349
#    macro avg       0.76      0.74      0.73      3349
# weighted avg       0.76      0.74      0.74      3349
#
# classification report               precision    recall  f1-score   support
#
#            0       0.70      0.88      0.78      1760
#            1       0.82      0.59      0.68      1589
#
#     accuracy                           0.74      3349
#    macro avg       0.76      0.74      0.73      3349
# weighted avg       0.76      0.74      0.74      3349

# %%
vc1=VotingClassifier(estimators=models,voting='soft')
vc1.fit(xtrain,ytrain)
ypred=vc1.predict(xtest)
cr=classification_report(ytest,ypred)
print(f"classification report {cr}")
# Out:
# classification report               precision    recall  f1-score   support
#
#            0       0.79      0.80      0.79      1760
#            1       0.77      0.77      0.77      1589
#
#     accuracy                           0.78      3349
#    macro avg       0.78      0.78      0.78      3349
# weighted avg       0.78      0.78      0.78      3349
#
# classification report               precision    recall  f1-score   support
#
#            0       0.79      0.80      0.79      1760
#            1       0.77      0.77      0.77      1589
#
#     accuracy                           0.78      3349
#    macro avg       0.78      0.78      0.78      3349
# weighted avg       0.78      0.78      0.78      3349

# %% [markdown]
# # Boosting

# %%
from sklearn.ensemble import AdaBoostClassifier

# %%
ada=AdaBoostClassifier()
ada.fit(xtrain,ytrain)
ypred=ada.predict(xtest)
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.82      0.85      0.84      1760
#            1       0.83      0.80      0.81      1589
#
#     accuracy                           0.83      3349
#    macro avg       0.83      0.83      0.83      3349
# weighted avg       0.83      0.83      0.83      3349
#
#               precision    recall  f1-score   support
#
#            0       0.82      0.85      0.84      1760
#            1       0.83      0.80      0.81      1589
#
#     accuracy                           0.83      3349
#    macro avg       0.83      0.83      0.83      3349
# weighted avg       0.83      0.83      0.83      3349

# %%
from sklearn.ensemble import GradientBoostingClassifier

# %%
gb=GradientBoostingClassifier()
gb.fit(xtrain,ytrain)
ypred=gb.predict(xtest)
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.82      0.84      1760
#            1       0.81      0.86      0.83      1589
#
#     accuracy                           0.84      3349
#    macro avg       0.84      0.84      0.84      3349
# weighted avg       0.84      0.84      0.84      3349
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.82      0.84      1760
#            1       0.81      0.86      0.83      1589
#
#     accuracy                           0.84      3349
#    macro avg       0.84      0.84      0.84      3349
# weighted avg       0.84      0.84      0.84      3349

# %%
pip install -U --ignore-installed python-openstackclient
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Collecting python-openstackclient
#   Using cached python_openstackclient-6.2.0-py3-none-any.whl (1.1 MB)
# Collecting python-cinderclient>=3.3.0
#   Using cached python_cinderclient-9.3.0-py3-none-any.whl (255 kB)
# Collecting stevedore>=2.0.1
#   Using cached stevedore-5.1.0-py3-none-any.whl (49 kB)
# Collecting oslo.utils>=3.33.0
#   Using cached oslo.utils-6.2.0-py3-none-any.whl (101 kB)
# Collecting cliff>=3.5.0
#   Using cached cliff-4.3.0-py3-none-any.whl (80 kB)
# Collecting iso8601>=0.1.11
#   Using cached iso8601-2.0.0-py3-none-any.whl (7.5 kB)
# Collecting pbr!=2.1.0,>=2.0.0
#   Using cached pbr-5.11.1-py2.py3-none-any.whl (112 kB)
# Collecting python-novaclient>=18.1.0
#   Using cached python_novaclient-18.3.0-py3-none-any.whl (335 kB)
# Collecting osc-lib>=2.3.0
#   Using cached osc_lib-2.8.0-py3-none-any.whl (89 kB)
# Collecting openstacksdk>=0.103.0
#   Using cached openstacksdk-1.3.1-py3-none-any.whl (1.6 MB)
# Collecting oslo.i18n>=3.15.3
#   Using cached oslo.i18n-6.0.0-py3-none-any.whl (46 kB)
# Collecting python-keystoneclient>=3.22.0
#   Using cached python_keystoneclient-5.1.0-py3-none-any.whl (398 kB)
# Collecting importlib-metadata>=4.4
#   Using cached importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Collecting PyYAML>=3.12
#   Using cached PyYAML-6.0.1-cp310-cp310-win_amd64.whl (145 kB)
# Collecting PrettyTable>=0.7.2
#   Using cached prettytable-3.8.0-py3-none-any.whl (27 kB)
# Collecting cmd2>=1.0.0
#   Using cached cmd2-2.4.3-py3-none-any.whl (147 kB)
# Collecting autopage>=0.4.0
#   Using cached autopage-0.5.1-py3-none-any.whl (29 kB)
# Collecting jmespath>=0.9.0
#   Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting dogpile.cache>=0.6.5
#   Using cached dogpile.cache-1.2.2-py3-none-any.whl (52 kB)
# Collecting requestsexceptions>=1.2.0
#   Using cached requestsexceptions-1.4.0-py2.py3-none-any.whl (3.8 kB)
# Collecting decorator>=4.4.1
#   Using cached decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Collecting jsonpatch!=1.20,>=1.16
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting appdirs>=1.3.0
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting os-service-types>=1.7.0
#   Using cached os_service_types-1.7.0-py2.py3-none-any.whl (24 kB)
# Collecting netifaces>=0.10.4
#   Using cached netifaces-0.11.0.tar.gz (30 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting cryptography>=2.7
#   Using cached cryptography-41.0.2-cp37-abi3-win_amd64.whl (2.6 MB)
# Collecting keystoneauth1>=3.18.0
#   Using cached keystoneauth1-5.2.1-py3-none-any.whl (322 kB)
# Collecting simplejson>=3.5.1
#   Using cached simplejson-3.19.1-cp310-cp310-win_amd64.whl (75 kB)
# Collecting pytz>=2013.6
#   Using cached pytz-2023.3-py2.py3-none-any.whl (502 kB)
# Collecting packaging>=20.4
#   Using cached packaging-23.1-py3-none-any.whl (48 kB)
# Collecting tzdata>=2022.4
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Collecting netaddr>=0.7.18
#   Using cached netaddr-0.8.0-py2.py3-none-any.whl (1.9 MB)
# Collecting debtcollector>=1.2.0
#   Using cached debtcollector-2.5.0-py3-none-any.whl (23 kB)
# Collecting pyparsing>=2.1.0
#   Using cached pyparsing-3.1.0-py3-none-any.whl (102 kB)
# Collecting requests>=2.25.1
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting oslo.serialization!=2.19.1,>=2.18.0
#   Using cached oslo.serialization-5.1.1-py3-none-any.whl (25 kB)
# Collecting oslo.config>=5.2.0
#   Using cached oslo.config-9.1.1-py3-none-any.whl (128 kB)
# Collecting six>=1.10.0
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting pyreadline3
#   Using cached pyreadline3-3.4.1-py3-none-any.whl (95 kB)
# Collecting wcwidth>=0.1.7
#   Using cached wcwidth-0.2.6-py2.py3-none-any.whl (29 kB)
# Collecting attrs>=16.3.0
#   Using cached attrs-23.1.0-py3-none-any.whl (61 kB)
# Collecting pyperclip>=1.6
#   Using cached pyperclip-1.8.2-py3-none-any.whl
# Collecting cffi>=1.12
#   Using cached cffi-1.15.1-cp310-cp310-win_amd64.whl (179 kB)
# Collecting wrapt>=1.7.0
#   Using cached wrapt-1.15.0-cp310-cp310-win_amd64.whl (36 kB)
# Collecting typing-extensions>=4.0.1
#   Using cached typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Collecting zipp>=0.5
#   Using cached zipp-3.16.2-py3-none-any.whl (7.2 kB)
# Collecting jsonpointer>=1.9
#   Using cached jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Collecting rfc3986>=1.2.0
#   Using cached rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Collecting msgpack>=0.5.2
#   Using cached msgpack-1.0.5-cp310-cp310-win_amd64.whl (61 kB)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.2.0-cp310-cp310-win_amd64.whl (96 kB)
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.0.4-py3-none-any.whl (123 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2023.5.7-py3-none-any.whl (156 kB)
# Collecting pycparser
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Building wheels for collected packages: netifaces
#   Building wheel for netifaces (setup.py): started
#   Building wheel for netifaces (setup.py): finished with status 'error'
#   Running setup.py clean for netifaces
# Failed to build netifaces
# Installing collected packages: wcwidth, requestsexceptions, pytz, pyreadline3, pyperclip, netifaces, netaddr, msgpack, appdirs, zipp, wrapt, urllib3, tzdata, typing-extensions, six, simplejson, rfc3986, PyYAML, pyparsing, pycparser, PrettyTable, pbr, packaging, jsonpointer, jmespath, iso8601, idna, decorator, charset-normalizer, certifi, autopage, attrs, stevedore, requests, oslo.i18n, os-service-types, jsonpatch, importlib-metadata, debtcollector, cmd2, cffi, oslo.utils, oslo.config, keystoneauth1, dogpile.cache, cryptography, cliff, python-cinderclient, oslo.serialization, openstacksdk, python-novaclient, python-keystoneclient, osc-lib, python-openstackclient
#   Running setup.py install for netifaces: started
#   Running setup.py install for netifaces: finished with status 'error'
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# Collecting python-openstackclient
#   Using cached python_openstackclient-6.2.0-py3-none-any.whl (1.1 MB)
# Collecting python-cinderclient>=3.3.0
#   Using cached python_cinderclient-9.3.0-py3-none-any.whl (255 kB)
# Collecting stevedore>=2.0.1
#   Using cached stevedore-5.1.0-py3-none-any.whl (49 kB)
# Collecting oslo.utils>=3.33.0
#   Using cached oslo.utils-6.2.0-py3-none-any.whl (101 kB)
# Collecting cliff>=3.5.0
#   Using cached cliff-4.3.0-py3-none-any.whl (80 kB)
# Collecting iso8601>=0.1.11
#   Using cached iso8601-2.0.0-py3-none-any.whl (7.5 kB)
# Collecting pbr!=2.1.0,>=2.0.0
#   Using cached pbr-5.11.1-py2.py3-none-any.whl (112 kB)
# Collecting python-novaclient>=18.1.0
#   Using cached python_novaclient-18.3.0-py3-none-any.whl (335 kB)
# Collecting osc-lib>=2.3.0
#   Using cached osc_lib-2.8.0-py3-none-any.whl (89 kB)
# Collecting openstacksdk>=0.103.0
#   Using cached openstacksdk-1.3.1-py3-none-any.whl (1.6 MB)
# Collecting oslo.i18n>=3.15.3
#   Using cached oslo.i18n-6.0.0-py3-none-any.whl (46 kB)
# Collecting python-keystoneclient>=3.22.0
#   Using cached python_keystoneclient-5.1.0-py3-none-any.whl (398 kB)
# Collecting importlib-metadata>=4.4
#   Using cached importlib_metadata-6.8.0-py3-none-any.whl (22 kB)
# Collecting PyYAML>=3.12
#   Using cached PyYAML-6.0.1-cp310-cp310-win_amd64.whl (145 kB)
# Collecting PrettyTable>=0.7.2
#   Using cached prettytable-3.8.0-py3-none-any.whl (27 kB)
# Collecting cmd2>=1.0.0
#   Using cached cmd2-2.4.3-py3-none-any.whl (147 kB)
# Collecting autopage>=0.4.0
#   Using cached autopage-0.5.1-py3-none-any.whl (29 kB)
# Collecting jmespath>=0.9.0
#   Using cached jmespath-1.0.1-py3-none-any.whl (20 kB)
# Collecting dogpile.cache>=0.6.5
#   Using cached dogpile.cache-1.2.2-py3-none-any.whl (52 kB)
# Collecting requestsexceptions>=1.2.0
#   Using cached requestsexceptions-1.4.0-py2.py3-none-any.whl (3.8 kB)
# Collecting decorator>=4.4.1
#   Using cached decorator-5.1.1-py3-none-any.whl (9.1 kB)
# Collecting jsonpatch!=1.20,>=1.16
#   Using cached jsonpatch-1.33-py2.py3-none-any.whl (12 kB)
# Collecting appdirs>=1.3.0
#   Using cached appdirs-1.4.4-py2.py3-none-any.whl (9.6 kB)
# Collecting os-service-types>=1.7.0
#   Using cached os_service_types-1.7.0-py2.py3-none-any.whl (24 kB)
# Collecting netifaces>=0.10.4
#   Using cached netifaces-0.11.0.tar.gz (30 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting cryptography>=2.7
#   Using cached cryptography-41.0.2-cp37-abi3-win_amd64.whl (2.6 MB)
# Collecting keystoneauth1>=3.18.0
#   Using cached keystoneauth1-5.2.1-py3-none-any.whl (322 kB)
# Collecting simplejson>=3.5.1
#   Using cached simplejson-3.19.1-cp310-cp310-win_amd64.whl (75 kB)
# Collecting pytz>=2013.6
#   Using cached pytz-2023.3-py2.py3-none-any.whl (502 kB)
# Collecting packaging>=20.4
#   Using cached packaging-23.1-py3-none-any.whl (48 kB)
# Collecting tzdata>=2022.4
#   Using cached tzdata-2023.3-py2.py3-none-any.whl (341 kB)
# Collecting netaddr>=0.7.18
#   Using cached netaddr-0.8.0-py2.py3-none-any.whl (1.9 MB)
# Collecting debtcollector>=1.2.0
#   Using cached debtcollector-2.5.0-py3-none-any.whl (23 kB)
# Collecting pyparsing>=2.1.0
#   Using cached pyparsing-3.1.0-py3-none-any.whl (102 kB)
# Collecting requests>=2.25.1
#   Using cached requests-2.31.0-py3-none-any.whl (62 kB)
# Collecting oslo.serialization!=2.19.1,>=2.18.0
#   Using cached oslo.serialization-5.1.1-py3-none-any.whl (25 kB)
# Collecting oslo.config>=5.2.0
#   Using cached oslo.config-9.1.1-py3-none-any.whl (128 kB)
# Collecting six>=1.10.0
#   Using cached six-1.16.0-py2.py3-none-any.whl (11 kB)
# Collecting pyreadline3
#   Using cached pyreadline3-3.4.1-py3-none-any.whl (95 kB)
# Collecting wcwidth>=0.1.7
#   Using cached wcwidth-0.2.6-py2.py3-none-any.whl (29 kB)
# Collecting attrs>=16.3.0
#   Using cached attrs-23.1.0-py3-none-any.whl (61 kB)
# Collecting pyperclip>=1.6
#   Using cached pyperclip-1.8.2-py3-none-any.whl
# Collecting cffi>=1.12
#   Using cached cffi-1.15.1-cp310-cp310-win_amd64.whl (179 kB)
# Collecting wrapt>=1.7.0
#   Using cached wrapt-1.15.0-cp310-cp310-win_amd64.whl (36 kB)
# Collecting typing-extensions>=4.0.1
#   Using cached typing_extensions-4.7.1-py3-none-any.whl (33 kB)
# Collecting zipp>=0.5
#   Using cached zipp-3.16.2-py3-none-any.whl (7.2 kB)
# Collecting jsonpointer>=1.9
#   Using cached jsonpointer-2.4-py2.py3-none-any.whl (7.8 kB)
# Collecting rfc3986>=1.2.0
#   Using cached rfc3986-2.0.0-py2.py3-none-any.whl (31 kB)
# Collecting msgpack>=0.5.2
#   Using cached msgpack-1.0.5-cp310-cp310-win_amd64.whl (61 kB)
# Collecting charset-normalizer<4,>=2
#   Using cached charset_normalizer-3.2.0-cp310-cp310-win_amd64.whl (96 kB)
# Collecting urllib3<3,>=1.21.1
#   Using cached urllib3-2.0.4-py3-none-any.whl (123 kB)
# Collecting idna<4,>=2.5
#   Using cached idna-3.4-py3-none-any.whl (61 kB)
# Collecting certifi>=2017.4.17
#   Using cached certifi-2023.5.7-py3-none-any.whl (156 kB)
# Collecting pycparser
#   Using cached pycparser-2.21-py2.py3-none-any.whl (118 kB)
# Building wheels for collected packages: netifaces
#   Building wheel for netifaces (setup.py): started
#   Building wheel for netifaces (setup.py): finished with status 'error'
#   Running setup.py clean for netifaces
# Failed to build netifaces
# Installing collected packages: wcwidth, requestsexceptions, pytz, pyreadline3, pyperclip, netifaces, netaddr, msgpack, appdirs, zipp, wrapt, urllib3, tzdata, typing-extensions, six, simplejson, rfc3986, PyYAML, pyparsing, pycparser, PrettyTable, pbr, packaging, jsonpointer, jmespath, iso8601, idna, decorator, charset-normalizer, certifi, autopage, attrs, stevedore, requests, oslo.i18n, os-service-types, jsonpatch, importlib-metadata, debtcollector, cmd2, cffi, oslo.utils, oslo.config, keystoneauth1, dogpile.cache, cryptography, cliff, python-cinderclient, oslo.serialization, openstacksdk, python-novaclient, python-keystoneclient, osc-lib, python-openstackclient
#   Running setup.py install for netifaces: started
#   Running setup.py install for netifaces: finished with status 'error'
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [7 lines of output]
#   D:\anaconda python\lib\site-packages\setuptools\config\setupcfg.py:508: SetuptoolsDeprecationWarning: The license_file parameter is deprecated, use license_files instead.
#     warnings.warn(msg, warning_class)
#   running bdist_wheel
#   running build
#   running build_ext
#   building 'netifaces' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for netifaces
#   error: subprocess-exited-with-error
#
#   Running setup.py install for netifaces did not run successfully.
#   exit code: 1
#
#   [9 lines of output]
#   D:\anaconda python\lib\site-packages\setuptools\config\setupcfg.py:508: SetuptoolsDeprecationWarning: The license_file parameter is deprecated, use license_files instead.
#     warnings.warn(msg, warning_class)
#   running install
#   D:\anaconda python\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#     warnings.warn(
#   running build
#   running build_ext
#   building 'netifaces' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# Encountered error while trying to install package.
#
# netifaces
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.
#   error: subprocess-exited-with-error
#
#   python setup.py bdist_wheel did not run successfully.
#   exit code: 1
#
#   [7 lines of output]
#   D:\anaconda python\lib\site-packages\setuptools\config\setupcfg.py:508: SetuptoolsDeprecationWarning: The license_file parameter is deprecated, use license_files instead.
#     warnings.warn(msg, warning_class)
#   running bdist_wheel
#   running build
#   running build_ext
#   building 'netifaces' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for netifaces
#   error: subprocess-exited-with-error
#
#   Running setup.py install for netifaces did not run successfully.
#   exit code: 1
#
#   [9 lines of output]
#   D:\anaconda python\lib\site-packages\setuptools\config\setupcfg.py:508: SetuptoolsDeprecationWarning: The license_file parameter is deprecated, use license_files instead.
#     warnings.warn(msg, warning_class)
#   running install
#   D:\anaconda python\lib\site-packages\setuptools\command\install.py:34: SetuptoolsDeprecationWarning: setup.py install is deprecated. Use build and pip and other standards-based tools.
#     warnings.warn(
#   running build
#   running build_ext
#   building 'netifaces' extension
#   error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#   [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
# error: legacy-install-failure
#
# Encountered error while trying to install package.
#
# netifaces
#
# note: This is an issue with the package mentioned above, not pip.
# hint: See above for output from the failure.

# %%
pip install xgboost
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xgboost in c:\users\hp\appdata\roaming\python\python310\site-packages (1.7.6)
# Requirement already satisfied: scipy in d:\anaconda python\lib\site-packages (from xgboost) (1.10.0)
# Requirement already satisfied: numpy in d:\anaconda python\lib\site-packages (from xgboost) (1.23.5)
# Note: you may need to restart the kernel to use updated packages.
# Defaulting to user installation because normal site-packages is not writeable
# Requirement already satisfied: xgboost in c:\users\hp\appdata\roaming\python\python310\site-packages (1.7.6)
# Requirement already satisfied: scipy in d:\anaconda python\lib\site-packages (from xgboost) (1.10.0)
# Requirement already satisfied: numpy in d:\anaconda python\lib\site-packages (from xgboost) (1.23.5)
# Note: you may need to restart the kernel to use updated packages.

# %%
from xgboost import XGBClassifier

# %%
xgb=XGBClassifier()
xgb.fit(xtrain,ytrain)
ypred=xgb.predict(xtest)
print(classification_report(ytest,ypred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.88      0.82      0.85      1760
#            1       0.82      0.87      0.84      1589
#
#     accuracy                           0.85      3349
#    macro avg       0.85      0.85      0.85      3349
# weighted avg       0.85      0.85      0.85      3349
#
#               precision    recall  f1-score   support
#
#            0       0.88      0.82      0.85      1760
#            1       0.82      0.87      0.84      1589
#
#     accuracy                           0.85      3349
#    macro avg       0.85      0.85      0.85      3349
# weighted avg       0.85      0.85      0.85      3349
